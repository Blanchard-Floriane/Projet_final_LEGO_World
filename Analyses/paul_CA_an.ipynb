# %%
import pandas as pd
import numpy as np
import re
import datetime
from datetime import timedelta
import matplotlib.pyplot as plt

# %%
df_CA= pd.read_csv("../Datas/df_CA_lego_paul.csv")

# %%
df_CA_T = df_CA.set_index('(mDKK)').T
df_CA_T
# Out:
# (mDKK)  Revenue  Expenses  Operating profit  Financial income and expenses  \
# 1995     6844.0       NaN               NaN                            NaN
# 1996     7534.0       NaN               NaN                            NaN
# 1997     7616.0       NaN               NaN                            NaN
# 1998     7680.0       NaN               NaN                            NaN
# 1999     9808.0       NaN               NaN                            NaN
# 2000     9467.0       NaN               NaN                            NaN
# 2001     9000.0    8142.0             736.0                          215.0
# 2002     9601.0    8795.0             806.0                          189.0
# 2003     6792.0    7902.0            1565.0                           67.0
# 2004     6315.0    6252.0            1162.0                           75.0
# 2005     7050.0    6582.0             459.0                            3.0
# ...

# %%
plt.figure(figsize=(8, 6))
plt.plot(df_CA_T['Revenue'], label='Revenue')
plt.plot(df_CA_T['Profit before income tax'], label='Profit before income tax')

plt.xticks(df_CA_T.index[::3], df_CA_T.index[::3])

plt.show()
